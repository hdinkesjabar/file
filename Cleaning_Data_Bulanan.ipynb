# %%
import pandas as pd
import glob
import os

# %%
fff = glob.glob("/content/*.xlsx")
fff
# Out:
# ['/content/Jumlah Calon Pengantin (Catin) yang Dilayani.xlsx',
#  '/content/Jumlah Sasaran Balita untuk Diukur.xlsx',
#  '/content/Jumlah Sasaran Individu Calon Pengantin (Catin) yang Diperiksa.xlsx',
#  '/content/Jumlah Sasaran Pasangan Calon Pengantin (Catin) yang Diperiksa.xlsx']

# %%
# Folder tempat file-file Excel disimpan
folder_path = "/content/"  # ganti sesuai folder Anda

# List untuk menampung dataframe tiap file
all_data = []

for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)

        # Baca data
        df = pd.read_excel(file_path)

        # Mapping nama kolom
        # bila diawali jumlah_xxx dan kategori_xxx akan diubah jadi Jumlah dan Kategori
        new_columns = {}
        for col in df.columns:
            if col.startswith("jumlah"):
                new_columns[col] = "Jumlah"
            elif col.startswith("kategori"):
                new_columns[col] = "Kategori"
            elif col != "Jenis":
                new_columns[col] = col.replace("_", " ").title()

        df = df.rename(columns=new_columns)


        # Ubah semua value teks jadi kapital di awal kata
        for col in df.select_dtypes(include=["object"]).columns:
            df[col] = df[col].astype(str).str.title()

        # Tambahkan kolom 'Jenis' sesuai nama file (tanpa .xlsx)
        jenis_value = os.path.splitext(file)[0]
        df["Jenis"] = jenis_value

        # Masukkan ke list
        all_data.append(df)

# Gabungkan semua dataframe
final_df = pd.concat(all_data, ignore_index=True)
final_df.head()
# Out:
#    Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 0   1             32    Jawa Barat                 3201     Kabupaten Bogor
# 1   2             32    Jawa Barat                 3201     Kabupaten Bogor
# 2   3             32    Jawa Barat                 3202  Kabupaten Sukabumi
# 3   4             32    Jawa Barat                 3202  Kabupaten Sukabumi
# 4   5             32    Jawa Barat                 3203   Kabupaten Cianjur
#
#   Jenis Kelamin  Jumlah Satuan  Tahun  \
# 0     Perempuan    9189  Orang   2024
# 1     Laki-Laki    7494  Orang   2024
# 2     Perempuan    5638  Orang   2024
# 3     Laki-Laki    3324  Orang   2024
# 4     Perempuan    4691  Orang   2024
#
#                                           Jenis
# 0  Jumlah Calon Pengantin (Catin) yang Dilayani
# 1  Jumlah Calon Pengantin (Catin) yang Dilayani
# 2  Jumlah Calon Pengantin (Catin) yang Dilayani
# 3  Jumlah Calon Pengantin (Catin) yang Dilayani
# 4  Jumlah Calon Pengantin (Catin) yang Dilayani

# %%
final_df.tail()
# Out:
#      Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 237  23             32    Jawa Barat                 3275         Kota Bekasi
# 238  24             32    Jawa Barat                 3276          Kota Depok
# 239  25             32    Jawa Barat                 3277         Kota Cimahi
# 240  26             32    Jawa Barat                 3278    Kota Tasikmalaya
# 241  27             32    Jawa Barat                 3279         Kota Banjar
#
#     Jenis Kelamin  Jumlah    Satuan  Tahun  \
# 237           NaN    8976  Pasangan   2024
# 238           NaN    2981  Pasangan   2024
# 239           NaN    2616  Pasangan   2024
# 240           NaN    2879  Pasangan   2024
# 241           NaN     707  Pasangan   2024
#
#                                                  Jenis
# 237  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 238  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 239  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 240  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 241  Jumlah Sasaran Pasangan Calon Pengantin (Catin...

# %%
final_df[final_df["Jenis Kelamin"].isnull() == 1]
# Out:
#      Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 54    1             32    Jawa Barat                 3201     Kabupaten Bogor
# 55    2             32    Jawa Barat                 3202  Kabupaten Sukabumi
# 56    3             32    Jawa Barat                 3203   Kabupaten Cianjur
# 57    4             32    Jawa Barat                 3204   Kabupaten Bandung
# 58    5             32    Jawa Barat                 3205     Kabupaten Garut
# ..   ..            ...           ...                  ...                 ...
# 237  23             32    Jawa Barat                 3275         Kota Bekasi
# 238  24             32    Jawa Barat                 3276          Kota Depok
# 239  25             32    Jawa Barat                 3277         Kota Cimahi
# 240  26             32    Jawa Barat                 3278    Kota Tasikmalaya
# 241  27             32    Jawa Barat                 3279         Kota Banjar
#
#     Jenis Kelamin  Jumlah    Satuan  Tahun  \
# 54            NaN  285930    Balita   2020
# 55            NaN   98822    Balita   2020
# 56            NaN  166031    Balita   2020
# 57            NaN   33944    Balita   2020
# 58            NaN   48730    Balita   2020
# ..            ...     ...       ...    ...
# 237           NaN    8976  Pasangan   2024
# 238           NaN    2981  Pasangan   2024
# 239           NaN    2616  Pasangan   2024
# 240           NaN    2879  Pasangan   2024
# 241           NaN     707  Pasangan   2024
#
#                                                  Jenis
# 54                  Jumlah Sasaran Balita untuk Diukur
# 55                  Jumlah Sasaran Balita untuk Diukur
# 56                  Jumlah Sasaran Balita untuk Diukur
# 57                  Jumlah Sasaran Balita untuk Diukur
# 58                  Jumlah Sasaran Balita untuk Diukur
# ..                                                 ...
# 237  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 238  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 239  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 240  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
# 241  Jumlah Sasaran Pasangan Calon Pengantin (Catin...
#
# [188 rows x 10 columns]

# %%
# Pastikan df sudah terbentuk
cols = list(final_df.columns)

# Pindahkan 'Jenis Kelamin' ke paling kanan
if "Jenis Kelamin" in cols:
    cols.append(cols.pop(cols.index("Jenis Kelamin")))
    final_df = final_df[cols]

print(final_df.columns)
# Out:
# Index(['Id', 'Kode Provinsi', 'Nama Provinsi', 'Kode Kabupaten Kota',
#        'Nama Kabupaten Kota', 'Jumlah', 'Satuan', 'Tahun', 'Jenis',
#        'Jenis Kelamin'],
#       dtype='object')

# %%
final_df_new = final_df.fillna("-")

# %%
final_df_new.tail()
# Out:
#      Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 237  23             32    Jawa Barat                 3275         Kota Bekasi
# 238  24             32    Jawa Barat                 3276          Kota Depok
# 239  25             32    Jawa Barat                 3277         Kota Cimahi
# 240  26             32    Jawa Barat                 3278    Kota Tasikmalaya
# 241  27             32    Jawa Barat                 3279         Kota Banjar
#
#      Jumlah    Satuan  Tahun  \
# 237    8976  Pasangan   2024
# 238    2981  Pasangan   2024
# 239    2616  Pasangan   2024
# 240    2879  Pasangan   2024
# 241     707  Pasangan   2024
#
#                                                  Jenis Jenis Kelamin
# 237  Jumlah Sasaran Pasangan Calon Pengantin (Catin...             -
# 238  Jumlah Sasaran Pasangan Calon Pengantin (Catin...             -
# 239  Jumlah Sasaran Pasangan Calon Pengantin (Catin...             -
# 240  Jumlah Sasaran Pasangan Calon Pengantin (Catin...             -
# 241  Jumlah Sasaran Pasangan Calon Pengantin (Catin...             -

# %%
final_df_new.to_excel("Hasil_Gabungan 2.xlsx", index=False)

# %%
name_map = {
    'Kabupaten Bandung': 'Bandung Regency',
    'Kabupaten Bandung Barat': 'West Bandung Regency',
    'Kabupaten Bekasi': 'Bekasi Regency',
    'Kabupaten Bogor': 'Bogor Regency',
    'Kabupaten Ciamis': 'Ciamis Regency',
    'Kabupaten Cianjur': 'Cianjur Regency',
    'Kabupaten Cirebon': 'Cirebon Regency',
    'Kabupaten Garut': 'Garut Regency',
    'Kabupaten Indramayu': 'Indramayu Regency',
    'Kabupaten Karawang': 'Karawang Regency',
    'Kabupaten Kuningan': 'Kuningan Regency',
    'Kabupaten Majalengka': 'Majalengka Regency',
    'Kabupaten Pangandaran': 'Pangandaran Regency',
    'Kabupaten Purwakarta': 'Purwakarta Regency',
    'Kabupaten Subang': 'Subang Regency',
    'Kabupaten Sukabumi': 'Sukabumi',
    'Kabupaten Sumedang': 'Sumedang Regency',
    'Kabupaten Tasikmalaya': 'Tasikmalaya Regency',
    'Kota Bandung': 'Bandung City',
    'Kota Banjar': 'Banjar City',
    'Kota Bekasi': 'Bekasi City',
    'Kota Bogor': 'Bogor City',
    'Kota Cimahi': 'Cimahi City',
    'Kota Cirebon': 'Cirebon City',
    'Kota Depok': 'Depok City',
    'Kota Sukabumi': 'Sukabumi City',
    'Kota Tasikmalaya': 'Tasikmalaya City'
}

# MEMBUAT KOLOM BARU DENGAN NAMA SESUAI GOOGLE
# Mengganti "Nama Kabupaten Kota" dengan nama kolom
final_df_new['Region Google'] = final_df_new['Nama Kabupaten Kota'].map(name_map).fillna(final_df_new['Nama Kabupaten Kota'])

print("✅ Selesai! Kolom Region_Google untuk Looker Studio sudah ditambahkan.")
# Out:
# ✅ Selesai! Kolom Region_Google untuk Looker Studio sudah ditambahkan.

# %%
import pandas as pd
import glob
import os

# %%
ggg = glob.glob("/content/bulan/*.xlsx")
ggg
# Out:
# ['/content/bulan/Jumlah Bumil Diperiksa ANC 6x.xlsx',
#  '/content/bulan/Jumlah Balita Gizi Kurang yang Mendapatkan Makanan Tambahan.xlsx',
#  '/content/bulan/Jumlah Anak Usia 6-23 Bulan yang Mendapatkan MPASI Baik.xlsx',
#  '/content/bulan/Jumlah Ibu Hamil Mengonsumi Tablet Tambah Darah (TTD) Minimal 90 Tablet Selama Kehamilan.xlsx',
#  '/content/bulan/Jumlah Bayi Usia Kurang dari 6 Bulan yang Mendapatkan ASI Eksklusif.xlsx',
#  '/content/bulan/Jumlah Remaja Putri Mengonsumi Tablet Tambah Darah (TTD).xlsx',
#  '/content/bulan/Jumlah Ibu Hamil Kurang Energi Kronik (KEK) yang Mendapatkan Tambahan Asupan Gizi.xlsx']

# %%
# Folder tempat file-file Excel disimpan
folder_path = "/content/bulan/"  # ganti sesuai folder Anda

# List untuk menampung dataframe tiap file
all_data = []

for file in os.listdir(folder_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(folder_path, file)

        # Baca data
        df = pd.read_excel(file_path)

        # Mapping nama kolom
        # bila diawali jumlah_xxx dan kategori_xxx akan diubah jadi Jumlah dan Kategori
        new_columns = {}
        for col in df.columns:
            if col.startswith("jumlah"):
                new_columns[col] = "Jumlah"
            elif col.startswith("_jumlah"):
                new_columns[col] = "Jumlah"
            elif col.startswith("kategori"):
                new_columns[col] = "Kategori"
            elif col != "Jenis":
                new_columns[col] = col.replace("_", " ").title()

        df = df.rename(columns=new_columns)


        # Ubah semua value teks jadi kapital di awal kata
        for col in df.select_dtypes(include=["object"]).columns:
            df[col] = df[col].astype(str).str.title()

        # Tambahkan kolom 'Jenis' sesuai nama file (tanpa .xlsx)
        jenis_value = os.path.splitext(file)[0]
        df["Jenis"] = jenis_value

        # Masukkan ke list
        all_data.append(df)

# Gabungkan semua dataframe
final_df = pd.concat(all_data, ignore_index=True)
final_df.head()
# Out:
#    Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 0   1             32    Jawa Barat                 3201     Kabupaten Bogor
# 1   2             32    Jawa Barat                 3202  Kabupaten Sukabumi
# 2   3             32    Jawa Barat                 3203   Kabupaten Cianjur
# 3   4             32    Jawa Barat                 3204   Kabupaten Bandung
# 4   5             32    Jawa Barat                 3205     Kabupaten Garut
#
#    Jumlah Satuan Bulan  Tahun                          Jenis
# 0   39640  Orang  Juli   2024  Jumlah Bumil Diperiksa ANC 6x
# 1   20153  Orang  Juli   2024  Jumlah Bumil Diperiksa ANC 6x
# 2   18149  Orang  Juli   2024  Jumlah Bumil Diperiksa ANC 6x
# 3   28048  Orang  Juli   2024  Jumlah Bumil Diperiksa ANC 6x
# 4   20949  Orang  Juli   2024  Jumlah Bumil Diperiksa ANC 6x

# %%
name_map = {
    'Kabupaten Bandung': 'Bandung Regency',
    'Kabupaten Bandung Barat': 'West Bandung Regency',
    'Kabupaten Bekasi': 'Bekasi Regency',
    'Kabupaten Bogor': 'Bogor Regency',
    'Kabupaten Ciamis': 'Ciamis Regency',
    'Kabupaten Cianjur': 'Cianjur Regency',
    'Kabupaten Cirebon': 'Cirebon Regency',
    'Kabupaten Garut': 'Garut Regency',
    'Kabupaten Indramayu': 'Indramayu Regency',
    'Kabupaten Karawang': 'Karawang Regency',
    'Kabupaten Kuningan': 'Kuningan Regency',
    'Kabupaten Majalengka': 'Majalengka Regency',
    'Kabupaten Pangandaran': 'Pangandaran Regency',
    'Kabupaten Purwakarta': 'Purwakarta Regency',
    'Kabupaten Subang': 'Subang Regency',
    'Kabupaten Sukabumi': 'Sukabumi',
    'Kabupaten Sumedang': 'Sumedang Regency',
    'Kabupaten Tasikmalaya': 'Tasikmalaya Regency',
    'Kota Bandung': 'Bandung City',
    'Kota Banjar': 'Banjar City',
    'Kota Bekasi': 'Bekasi City',
    'Kota Bogor': 'Bogor City',
    'Kota Cimahi': 'Cimahi City',
    'Kota Cirebon': 'Cirebon City',
    'Kota Depok': 'Depok City',
    'Kota Sukabumi': 'Sukabumi City',
    'Kota Tasikmalaya': 'Tasikmalaya City'
}

# MEMBUAT KOLOM BARU DENGAN NAMA SESUAI GOOGLE
# Mengganti "Nama Kabupaten Kota" dengan nama kolom
final_df['Region Google'] = final_df['Nama Kabupaten Kota'].map(name_map).fillna(final_df['Nama Kabupaten Kota'])

print("✅ Selesai! Kolom Region_Google untuk Looker Studio sudah ditambahkan.")
# Out:
# ✅ Selesai! Kolom Region_Google untuk Looker Studio sudah ditambahkan.

# %%
df_exclude = final_df[~final_df["Jenis"].isin([
    "Jumlah Ibu Hamil Kurang Energi Kronik (KEK) yang Mendapatkan Tambahan Asupan Gizi",
    "Jumlah Balita Gizi Kurang yang Mendapatkan Makanan Tambahan"
])]

# %%
final_df.to_excel("Hasil_Gabungan Bulan.xlsx", index=False)
df_exclude.to_excel("Hasil_Gabungan Bulan Exclude Balita Gizkur dan Bumil KEK.xlsx", index=False)

# %%
dx = pd.read_excel("/content/Jumlah Kelahiran Bayi .xlsx")
dx.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2   3             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3   4             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 4   5             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
#
#   status_kelahiran jenis_kelamin  jumlah_kelahiran satuan  tahun
# 0            HIDUP     LAKI-LAKI             61740   JIWA   2012
# 1            HIDUP     PEREMPUAN             49720   JIWA   2012
# 2             MATI     LAKI-LAKI                36   JIWA   2012
# 3             MATI     PEREMPUAN                47   JIWA   2012
# 4            HIDUP     LAKI-LAKI             22812   JIWA   2012

# %%
dx["Jenis"] = "Jumlah Kelahiran Bayi"

# %%
new_columns = {}
for col in dx.columns:
  if col.startswith("jumlah"):
    new_columns[col] = "Jumlah"
  elif col.startswith("Status"):
    new_columns[col] = "Kategori"
  elif col != "Jenis":
    new_columns[col] = col.replace("_", " ").title()

dx = dx.rename(columns=new_columns)
dx.head(5)
# Out:
#    Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2   3             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3   4             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 4   5             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
#
#   Status Kelahiran Jenis Kelamin  Jumlah Satuan  Tahun                  Jenis
# 0            HIDUP     LAKI-LAKI   61740   JIWA   2012  Jumlah Kelahiran Bayi
# 1            HIDUP     PEREMPUAN   49720   JIWA   2012  Jumlah Kelahiran Bayi
# 2             MATI     LAKI-LAKI      36   JIWA   2012  Jumlah Kelahiran Bayi
# 3             MATI     PEREMPUAN      47   JIWA   2012  Jumlah Kelahiran Bayi
# 4            HIDUP     LAKI-LAKI   22812   JIWA   2012  Jumlah Kelahiran Bayi

# %%
for col in dx.select_dtypes(include=["object"]).columns:
  dx[col] = dx[col].astype(str).str.title()
dx.head(5)
# Out:
#    Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 0   1             32    Jawa Barat                 3201     Kabupaten Bogor
# 1   2             32    Jawa Barat                 3201     Kabupaten Bogor
# 2   3             32    Jawa Barat                 3201     Kabupaten Bogor
# 3   4             32    Jawa Barat                 3201     Kabupaten Bogor
# 4   5             32    Jawa Barat                 3202  Kabupaten Sukabumi
#
#   Status Kelahiran Jenis Kelamin  Jumlah Satuan  Tahun                  Jenis
# 0            Hidup     Laki-Laki   61740   Jiwa   2012  Jumlah Kelahiran Bayi
# 1            Hidup     Perempuan   49720   Jiwa   2012  Jumlah Kelahiran Bayi
# 2             Mati     Laki-Laki      36   Jiwa   2012  Jumlah Kelahiran Bayi
# 3             Mati     Perempuan      47   Jiwa   2012  Jumlah Kelahiran Bayi
# 4            Hidup     Laki-Laki   22812   Jiwa   2012  Jumlah Kelahiran Bayi

# %%
name_map = {
    'Kabupaten Bandung': 'Bandung Regency',
    'Kabupaten Bandung Barat': 'West Bandung Regency',
    'Kabupaten Bekasi': 'Bekasi Regency',
    'Kabupaten Bogor': 'Bogor Regency',
    'Kabupaten Ciamis': 'Ciamis Regency',
    'Kabupaten Cianjur': 'Cianjur Regency',
    'Kabupaten Cirebon': 'Cirebon Regency',
    'Kabupaten Garut': 'Garut Regency',
    'Kabupaten Indramayu': 'Indramayu Regency',
    'Kabupaten Karawang': 'Karawang Regency',
    'Kabupaten Kuningan': 'Kuningan Regency',
    'Kabupaten Majalengka': 'Majalengka Regency',
    'Kabupaten Pangandaran': 'Pangandaran Regency',
    'Kabupaten Purwakarta': 'Purwakarta Regency',
    'Kabupaten Subang': 'Subang Regency',
    'Kabupaten Sukabumi': 'Sukabumi',
    'Kabupaten Sumedang': 'Sumedang Regency',
    'Kabupaten Tasikmalaya': 'Tasikmalaya Regency',
    'Kota Bandung': 'Bandung City',
    'Kota Banjar': 'Banjar City',
    'Kota Bekasi': 'Bekasi City',
    'Kota Bogor': 'Bogor City',
    'Kota Cimahi': 'Cimahi City',
    'Kota Cirebon': 'Cirebon City',
    'Kota Depok': 'Depok City',
    'Kota Sukabumi': 'Sukabumi City',
    'Kota Tasikmalaya': 'Tasikmalaya City'
}

# MEMBUAT KOLOM BARU DENGAN NAMA SESUAI GOOGLE
# Mengganti "Nama Kabupaten Kota" dengan nama kolom
dx['Region Google'] = dx['Nama Kabupaten Kota'].map(name_map).fillna(dx['Nama Kabupaten Kota'])

print("✅ Selesai! Kolom Region_Google untuk Looker Studio sudah ditambahkan.")
dx.to_excel("Jumlah Kelahiran Bayi Cleaned.xlsx", index=False)
print("✅ Selesai! Suda diexport.")
dx.head()
# Out:
# ✅ Selesai! Kolom Region_Google untuk Looker Studio sudah ditambahkan.
# ✅ Selesai! Suda diexport.
#    Id  Kode Provinsi Nama Provinsi  Kode Kabupaten Kota Nama Kabupaten Kota  \
# 0   1             32    Jawa Barat                 3201     Kabupaten Bogor
# 1   2             32    Jawa Barat                 3201     Kabupaten Bogor
# 2   3             32    Jawa Barat                 3201     Kabupaten Bogor
# 3   4             32    Jawa Barat                 3201     Kabupaten Bogor
# 4   5             32    Jawa Barat                 3202  Kabupaten Sukabumi
#
#   Status Kelahiran Jenis Kelamin  Jumlah Satuan  Tahun                  Jenis  \
# 0            Hidup     Laki-Laki   61740   Jiwa   2012  Jumlah Kelahiran Bayi
# 1            Hidup     Perempuan   49720   Jiwa   2012  Jumlah Kelahiran Bayi
# 2             Mati     Laki-Laki      36   Jiwa   2012  Jumlah Kelahiran Bayi
# 3             Mati     Perempuan      47   Jiwa   2012  Jumlah Kelahiran Bayi
# 4            Hidup     Laki-Laki   22812   Jiwa   2012  Jumlah Kelahiran Bayi
#
#    Region Google
# 0  Bogor Regency
# 1  Bogor Regency
# 2  Bogor Regency
# 3  Bogor Regency
# 4       Sukabumi
